# %%
import spotipy
import pandas as pd
from pprint import pprint
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import spotipy.oauth2 as oauth2
from bs4 import BeautifulSoup
from api_key import genius_api_key_id

from api_key import genius_client_id
from api_key import genius_client_secret
from api_key import SPOTIFY_CLIENT_ID
from api_key import SPOTIFY_CLIENT_SECRET
import lyricsgenius


# credentials = oauth2.SpotifyClientCredentials(
#        client_id=SPOTIFY_CLIENT_ID,
#        client_secret=SPOTIFY_CLIENT_SECRET)

# token = credentials.get_access_token()
# spotify = spotipy.Spotify(auth=token)

###EMPLOYS THE lyricsgenius library: https://github.com/johnwmillr/LyricsGenius

# %%
genius = lyricsgenius.Genius(genius_api_key_id)

# %%
######## FUNCTION TO PULL DATA FOR ANY ARTIST ######## 

def sample_data(artist_func):
    artist_1 = genius.search_artist(artist_func, max_songs="", sort="popularity")
    titles_func=[]
    x=0
    for item in artist_1.songs:
        titles.append(artist_1.songs[x].title)
        x+=1
        
    writers_func=[]
    for y in range(len(artist_1._songs)):
        for x in range(len(artist_1._songs[y].writer_artists)):
            writers_func.append(artist_1._songs[y].writer_artists[x]['name'])
    
    artist_samples_func=[]
    for y in range(len(artist_1.songs)):
        songs_sampled_func=[]
        for x in range(len(artist_1.songs[y]._body.get('song_relationships')[0]['songs'])):
            songs_sampled_func.append({artist_1.songs[y]._body.get('song_relationships')[0]['songs'][x]['primary_artist']['name']:artist_1.songs[y]._body.get('song_relationships')[0]['songs'][x]['title']})
        artist_samples_func.append({artist_1.songs[y].title:songs_sampled_func})


    sampled_songs_func=[]
    a=[]
    for item in artist_samples_func:
        for key, value in item.items():
            if value != a:
                for item in value:
                    for item in list(item.values()):
                        sampled_songs_func.append(item)
                        
    sampled_artists_func=[]
    a=[]
    for item in artist_samples_func:
        for key, value in item.items():
            if value != a:
                for items in value:
                    sampled_artists_func.append(list(items.keys())[0])
    
    df=pd.DataFrame()
    df_songs=[]
    df_artist=[]
    df_writers=[]
    df_writers=[]
    df_year=[]
    df_samples=[]
    df_album=[]
    df_samples_per_song=[]
    df_featured_artists=[]
    df_lyrics=[]
    df_img=[]
    a=[]
    df_sampled_in=[]
    df_api=[]
    df_path=[]
    df_description=[]
    df_id=[]
    df_stats=[]
    df_pageviews=[]
    df_apple_music_player_url=[]
    df_recording_location=[]
    df_release_date=[]
    df_writers_per_song=[]
    for x in range(len(artist_1._songs)):
        df_songs.append(artist_1._songs[x].title)
        df_artist.append(artist_1._songs[x].artist)
        df_writers_per_song=[]
        for y in range(len(artist_1._songs[x].writer_artists)):
            df_writers_per_song.append(artist_1._songs[x].writer_artists[y]['name'])
    df_writers.append(df_writers_per_song)
    df_samples.append(list(artist_samples[x].values())[0])
    df_album.append(artist_1.songs[x].album)
    df_year.append(artist_1.songs[x].year)
    df_img.append(artist_1.songs[x].song_art_image_url)

    featured_artists=[]
    featured_list=[]
    y=0
    featured_list=[]
    if artist._songs[x].featured_artists == a:
        featured_artists.append([])
    else:
        for y in range(len(artist._songs[x].featured_artists)):
            featured_list.append(artist._songs[x].featured_artists[y]['name'])
    df_featured_artists.append(featured_list)
    lyrics=artist.songs[x].to_dict
    df_lyrics.append(lyrics()['lyrics'])
    
    sampled_in=[]
    if len(artist_1.songs[x]._body.get('song_relationships')[1]['songs']) > 0:
        for y in range(len(artist_1.songs[x]._body.get('song_relationships')[1]['songs'])):
            sampled_in.append({(artist_1.songs[x]._body.get('song_relationships')[1]['songs'][y]['primary_artist']['name']):(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['title'])})
    else:
        sampled_in.append([])
    df_sampled_in.append(sampled_in)
    df_api.append(artist_1._songs[x]._body['api_path'])
    df_path.append(artist_1._songs[x]._body['url'])
    df_id.append(artist_1._songs[x]._body['id'])
    df_description.append(artist_1._songs[x]._body['description'])
    df_apple_music_player_url.append(artist_1._songs[x]._body['apple_music_player_url'])
    df_recording_location.append(artist_1._songs[x]._body['recording_location'])
    df_release_date.append(artist_1._songs[x]._body['release_date'])
    df_stats.append(artist_1._songs[x]._body['stats'])
    df_pageviews.append(artist_1._songs[x]._body['pageviews'])
    


    df['Performer']=df_artist
    df['Song']=df_songs
    df['Album']=df_album
    df['Year']=df_year
    df['Featuring']=df_featured_artists
    df['Writers']=df_writers
    df['Samples']=df_samples
    df['Sampled_In']=df_sampled_in
    df['Lyrics']=df_lyrics
    df['Image_URL']=df_img
    df['Description']=df_description
    df['API_path']=df_api
    df['URL']=df_path
    df['Release_Date']=df_release_date

    df['Music_Player_URL']=df_apple_music_player_url
    df['Song_Id']=df_id
    df["Reocrding_Location"]=df_recording_location
    df['Stats']=df_stats
    df['Pageviews']=df_pageviews


    return df

# %%
sample_data("Jay Z")
# Out:
# Searching for songs by Jay Z...
#
# Changing artist name to 'JAY-Z'
# Song 1: "Holy Grail"
# Song 2: "Part II (On The Run)"
# Song 3: "The Story of O.J."
# Song 4: "Tom Ford"
# Song 5: "4:44"
# Song 6: "FuckWithMeYouKnowIGotIt"
# Song 7: "Empire State of Mind"
# Song 8: "Oceans"
# Song 9: "99 Problems"
# Song 10: "Picasso Baby"
# Song 11: "Kill Jay Z"
# Song 12: "Renegade"
# Song 13: "Open Letter"
# Song 14: "Family Feud"
# Song 15: "Takeover"
# Song 16: "Run This Town"
# Song 17: "Heaven"
# Song 18: "Song Cry"
# Song 19: "Public Service Announcement"
# Song 20: "Smile"
# Song 21: "Big Pimpin'"
# Song 22: "Beach Is Better (Interlude)"
# Song 23: "BBC"
# Song 24: "We Made It Freestyle"
# Song 25: "Somewhereinamerica"
# Song 26: "Bam"
# Song 27: "Crown"
# Song 28: "'03 Bonnie & Clyde"
# Song 29: "La Familia"
# Song 30: "F.U.T.W"
# Song 31: "Glory"
# Song 32: "Izzo (H.O.V.A.)"
# Song 33: "Jay Z Blue"
# Song 34: "Young Forever"
# Song 35: "D'Evils"
# Song 36: "Hard Knock Life (Ghetto Anthem)"
# Song 37: "Can I Live"
# Song 38: "Lucifer"
# Song 39: "Caught Their Eyes"
# Song 40: "On To The Next One"
# Song 41: "Moment of Clarity"
# Song 42: "Moonlight"
# Song 43: "Marcy Me"
# Song 44: "Lost One"
# Song 45: "Dead Presidents II"
# Song 46: "A Star Is Born"
# Song 47: "Encore"
# Song 48: "100$ Bill"
# Song 49: "Nickels and Dimes"
# Song 50: "I Just Wanna Love U (Give it 2 Me)"
# Song 51: "Heart of the City (Ain't No Love)"
# Song 52: "U Don't Know"
# Song 53: "Brooklyn's Finest"
# Song 54: "Can I Get A…"
# Song 55: "Girls, Girls, Girls"
# Song 56: "Dead Presidents"
# Song 57: "Blueprint²"
# Song 58: "Dirt Off Your Shoulder"
# Song 59: "What More Can I Say"
# Song 60: "Legacy"
# Song 61: "Excuse Me Miss"
# Song 62: "Can't Knock the Hustle"
# Song 63: "Brooklyn (Go Hard)"
# Song 64: "Feelin' It"
# Song 65: "December 4th"
# Song 66: "D.O.A. (Death of Auto-Tune)"
# Song 67: "Where I'm From"
# Song 68: "Roc Boys (And the Winner Is)..."
# Song 69: "Never Change"
# Song 70: "Success"
# Song 71: "Blue's Freestyle/We Family"
# Song 72: "My 1st Song"
# Song 73: "Allure"
# Song 74: "Versus (Interlude)"
# Song 75: "22 Two's"
# Song 76: "Supa Ugly"
# Song 77: ""Grammy Family" Freestyle"
# Song 78: "Already Home"
# Song 79: "This Can't Be Life"
# Song 80: "Most Kingz"
# Song 81: "Politics as Usual"
# Song 82: "Ignorant Shit"
# Song 83: "Threat"
# Song 84: "A Week Ago"
# Song 85: "Change Clothes"
# Song 86: "Thank You"
# Song 87: "Imaginary Player"
# Song 88: "The Ruler's Back"
# Song 89: "Ain't No Nigga"
# Song 90: "Intro / A Million and One Questions / Rhyme No More"
# Song 91: "Regrets"
# Song 92: "Blueprint (Momma Loves Me)"
# Song 93: "Beach Chair"
# Song 94: "Venus vs. Mars"
# Song 95: "All I Need"
# Song 96: "I Know"
# Song 97: "The Bounce"
# Song 98: "Hate"
# Song 99: "Anything"
# Song 100: "Intro (Dynasty)"
# Song 101: "Bring It On"
# Song 102: "Justify My Thug"
# Song 103: "A Dream"
# Song 104: "30 Something"
# Song 105: "Hola' Hovito"
# Song 106: "Adnis"
# Song 107: "The Watcher 2"
# Song 108: "No Hook"
# Song 109: "What We Talkin' About"
# Song 110: "MaNyfaCedGod"
# Song 111: "American Dreamin'"
# Song 112: "Money, Cash, Hoes"
# Song 113: "You Must Love Me"
# Song 114: "Off That"
# Song 115: "Blue Magic"
# Song 116: "It's Hot (Some Like It Hot)"
# Song 117: "So Ambitious"
# Song 118: "Reminder"
# Song 119: "Friend or Foe"
# Song 120: "Soon You'll Understand"
# Song 121: "My President (Remix)"
# Song 122: "Pray"
# Song 123: "Nigga What, Nigga Who (Originator '99)"
# Song 124: "Breathe Easy (Lyrical Exercise)"
# Song 125: "Coming of Age"
# Song 126: "Cashmere Thoughts"
# Song 127: "Girls, Girls, Girls, Pt. 2"
# Song 128: "Streets Is Watching"
# Song 129: "Jigga That Nigga"
# Song 130: "Hello Brooklyn 2.0"
# Song 131: "Party Life"
# Song 132: "Say Hello"
# Song 133: "The Prelude"
# Song 134: "Do U Wanna Ride"
# "Magna Carta Holy Grail [Credits]" is not valid. Skipping.
# Song 135: "Meet The Parents"
# Song 136: "Lucky Me"
# Song 137: "Hovi Baby"
# Song 138: "Dead Presidents III"
# Song 139: "Bitches & Sisters"
# Song 140: "Real As It Gets"
# Song 141: "Show Me What You Got"
# Song 142: "Show You How"
# Song 143: "Tidal Freestyle (Stream Of Consciousness)"
# Song 144: "History"
# Song 145: "Where Have You Been"
# Song 146: "La-La-La (Excuse Me Miss Again)"
# Song 147: "Trouble"
# Song 148: "Guns & Roses"
# Song 149: "Kingdom Come"
# Song 150: "​spiritual"
# Song 151: "Jigga My Nigga"
# Song 152: "So Ghetto"
# Song 153: "Poppin' Tags"
# Song 154: "Fallin'"
# Song 155: "Oh My God"
# Song 156: "Reservoir Dogs"
# Song 157: "American Gangster"
# Song 158: "Diamond Is Forever"
# Song 159: "(Always Be My) Sunshine"
# Song 160: "Do It Again (Put Ya Hands Up)"
# Song 161: "Sweet"
# Song 162: "Dig a Hole"
# Song 163: "Beware (Jay-Z Remix)"
# Song 164: "Don't Let Me Die"
# Song 165: "Fuck All Nite"
# Song 166: "Ride or Die"
# Song 167: "Miss You (Remix)"
# Song 168: "The City Is Mine"
# Song 169: "Is That Yo Bitch?"
# Song 170: "Can I Live II"
# Song 171: "I Did It My Way"
# Song 172: "44 Four's"
# Song 173: "Some People Hate"
# Song 174: "1-900-Hustler"
# Song 175: "A Million and One Questions (Remix)"
# Song 176: "U Don't Know (Remix)"
# Song 177: "Streets Is Talking"
# Song 178: "Blow the Whistle"
# Song 179: "Some How Some Way"
# Song 180: "Who You Wit II"
# Song 181: "Come and Get Me"
# Song 182: "In My Lifetime (Remix)"
# Song 183: "Coming of Age (Da Sequel)"
# Song 184: "People Talkin'"
# Song 185: "8 Miles and Runnin'"
# Song 186: "Hova Song (Intro)"
# Song 187: "Watch Me"
# Song 188: "All Around the World"
# Song 189: "In My Lifetime"
# Song 190: "There's Been a Murder"
# Song 191: "Get Your Mind Right Mami"
# Song 192: "You, Me, Him and Her"
# Song 193: "Jockin' Jay-Z (Dopeboy Fresh)"
# Song 194: "I Know What Girls Like"
# Song 195: "It's Like That"
# Song 196: "Rap Game / Crack Game"
# Song 197: "Interlude"
# "4:44 [Credits]" is not valid. Skipping.
# Song 198: "Hollywood"
# Song 199: "Friend or Foe '98"
# Song 200: "Intro (American Gangster)"
# Song 201: "If I Should Die"
# Song 202: "30 Something (Remix)"
# Song 203: "Pump It Up Freestyle"
# Song 204: "Hey Papi"
# Song 205: "Nigga Please"
# Song 206: "Minority Report"
# Song 207: "Open Letter Part II (Remix)"
# Song 208: "Change the Game"
# Song 209: "A Billi"
# Song 210: "Dope Man"
# Song 211: "Girls, Girls, Girls (Remix)"
# Song 212: "Brooklyn High"
# Song 213: "Guilty Until Proven Innocent"
# "The Blueprint [Credits]" is not valid. Skipping.
# Song 214: "Stick 2 the Script"
# Song 215: "This Life Forever"
# Song 216: "If I Can't (Freestyle)"
# Song 217: "9/11 Freestyle"
# Song 218: "Things That U Do"
# Song 219: "Intro - Hand It Down"
# Song 220: "I Can't Get Wid Dat"
# Song 221: "I Made It"
# Song 222: "Squeeze 1st"
# Song 223: "Snoopy Track"
# Song 224: "Wishing on a Star"
# Song 225: "Girl's Best Friend"
# Song 226: "When the Money Goes"
# Song 227: "Addicted to the Game"
# Song 228: "Barclays Center Freestyle"
# Song 229: "2 Many Hoes"
# "Magna Carta Holy Grail [Album Art + Booklet]" is not valid. Skipping.
# Song 230: "Freestyle I Need Love"
# Song 231: "2002 Funk Flex Freestyle"
# Song 232: "Dead or Alive, Pt. 1"
# Song 233: "Early This Morning"
# Song 234: "A Ballad for the Fallen Soldier"
# Song 235: "NYMP"
# Song 236: "Real Niggaz"
# Song 237: "Parking Lot Pimpin'"
# Song 238: "Nipsey Hussle Freestyle"
# Song 239: "It's Alright"
# Song 240: "Bump, Bump, Bump (Freestyle)"
# Song 241: "S. Carter"
# Song 242: "Hustle Hard"
# Song 243: "Hova Song (Outro)"
# Song 244: "Tom Ford Remix"
# Song 245: "Rap City Freestyle"
# Song 246: "Paper Chase"
# Song 247: "What They Gonna Do"
# "OVO Sound Radio Episode 64 Tracklist" is not valid. Skipping.
# Song 248: "Don't You Know"
# Song 249: "Purchases  Basquiat Painting 'Mecca' For $4.5M"
# Song 250: "Anything (2006)"
# Song 251: "Can I Live Freestyle"
# Song 252: "Appearance on Real Time with Bill Maher"
# Song 253: "Young Gifted and Black"
# Song 254: "As One"
# "Reasonable Doubt Tracklist" is not valid. Skipping.
# Song 255: "Only a Customer"
# Song 256: "What They Gonna Do Part II"
# "On The Run Tour Setlist" is not valid. Skipping.
# Song 257: "Flow"
# Song 258: "Analyze This"
# "The Blueprint [Tracklist + Album Art]" is not valid. Skipping.
# "The Blueprint 3 [Tracklist + Album Art]" is not valid. Skipping.
# Song 259: "Face Off"
# Song 260: "Thoughts on Trayvon Martin, President Obama, Race"
# Song 261: "Who You Wit"
# "The Dynasty: Roc La Familia [Credits]" is not valid. Skipping.
# Song 262: "Ranking His Own Albums"
# Song 263: "Crew Love"
# Song 264: "Maybach Music 2 (Remix)"
# Song 265: "Blunts and Armadale (Freestyle)"
# "Reasonable Doubt [Album Artwork]" is not valid. Skipping.
# Song 266: "Pop 4 Roc"
# Song 267: "Excuse Me Miss Again (Remix)"
# Song 268: "Can't Knock the Hustle (Remix)"
# Song 269: "More Money, More Cash, More Hoes"
# Song 270: "Decoded: Part 1 (Excerpts)"
# Song 271: "Statement on Barneys Controversy"
# Song 272: ""Run This Town" Lawsuit"
# Song 273: "Tweets About New Album and New Rules"
# Song 274: "Ain't I"
# Song 275: "Hova Interlude"
# Song 276: "Understand Me"
# Song 277: "Dead or Alive, Part 2 (Disses 2pac)"
# Song 278: "Big Chips"
# "The Black Album Album Art" is not valid. Skipping.
# Song 279: "Stop 2.1"
# Song 280: "Dream. On."
# Song 281: "BK Anthem"
# Song 282: "20 Bag Shorty"
# Song 283: "Get My Shit Off"
# Song 284: "Pretty Lights (Empire State of Mind Remix)"
# Song 285: "You're Welcome"
# Song 286: "Can I Get A… (MTV Unplugged)"
# Song 287: "The War on Drugs is an Epic Fail"
# "​blonded RADIO Jay Z Interview" is not valid. Skipping.
# Song 288: "Backstage freestyle"
# Song 289: "Who Shot Ya (Freestyle)"
# Song 290: "Paradise"
# Song 291: "22 Days Challenge"
# Song 292: "Reach the Top"
# Song 293: "Celebration"
# Song 294: "American Boy (Live at Glastonbury 2008)"
# Song 295: "The Return"
# Song 296: "Laser In Ya Ear (Freestyle)"
# Song 297: "Murda Marcyville"
# Song 298: "Break Up (That's All We Do)"
# Song 299: "Marcy to Hollywood"
# Song 300: "Izzo (H.O.V.A.) [MTV Unplugged]"
# Song 301: "Troubles On My Mind"
# Song 302: "Can't Knock the Hustle (Fool's Paradise Remix)"
# Song 303: "Jay's Back, ASAP"
# "American Gangster [Tracklist + Album Art]" is not valid. Skipping.
# "The Dynasty: Roc La Familia Album Art" is not valid. Skipping.
# Song 304: "Best Rapper Alive Mashup"
# Song 305: "Stranded (Haiti Mon Amour)"
# Song 306: "Allure (Just Blaze Remix)"
# Song 307: "Stop"
# Song 308: "Rock Star Freestyle"
# "The Black Album [Booklet]" is not valid. Skipping.
# Song 309: "The Game Iz Mine"
# Song 310: "Stretch and Bobbito Show '95"
# "Magna Carta... Holy Grail [Booklet]" is not valid. Skipping.
# Song 311: "NBA Finals New Track Premiere Teaser"
# "Vol. 2... Hard Knock Life [Album Art]" is not valid. Skipping.
# Song 312: "Reebok (Interlude)"
# Song 313: "Beanie Sigel Freestlye"
# Song 314: "Hovi Baby (Remix)"
# Song 315: "Pretty Girls"
# Song 316: "Tweets on Tidal's Status"
# Song 317: "Big Pimpin' (MTV Unplugged)"
# Song 318: "Heart of the City (Ain't No Love) (MTV Unplugged)"
# Song 319: "Black Parade On December 4th"
# Song 320: "Criminology"
# Song 321: "Feelin' You in Stereo"
# Song 322: "Greatest MC"
# Song 323: "Hova Song (Full Version with 3 Verses)"
# Song 324: "Song Cry (MTV Unplugged)"
# Song 325: "Ignorant Shit (Original Version)"
# Song 326: "1999 Westwood Freestyle"
# Song 327: "Takeover (MTV Unplugged)"
# Song 328: "Statement on Racial Profiling Review at Barneys"
# Song 329: "Drop It Like It's Hot (Remix)"
# Song 330: "Looking @ My S Dots"
# "The Blueprint 3 [Booklet]" is not valid. Skipping.
# Song 331: "What the Game Made Me"
# Song 332: "I Just Wanna Love U (Give It 2 Me) (MTV Unplugged)"
# Song 333: "Jigga What, Jigga Who (MTV Unplugged)"
# Song 334: "People's Court"
# Song 335: "RD20"
# Song 336: "She's Coming Home With Me"
# Song 337: "Broken English & Drug Sellin'"
# Song 338: "Tru Life (intro)"
# Song 339: "Frontin' (Dancehall Remix)"
# Song 340: "Decoded: Part 2 (Excerpts)"
# "Vol. 3... Life and Times of S. Carter [Album Art]" is not valid. Skipping.
# Song 341: "The Return (Remix)"
# Song 342: "I Miss You (Remix)"
# Song 343: "Mo' Money"
# Song 344: "We Got Em Goin'"
# Song 345: "Can't Knock the Hustle / Family Affair (MTV Unplugged)"
# Song 346: "Decoded: Part 3 (Excerpts)"
# Song 347: "DJ Self Freestyle"
# Song 348: "Roc Army"
# Song 349: "2000 Tim Westwood Freestyle"
# Song 350: "Decoded: Epilogue (Excerpts)"
# Song 351: "Tidal B-Sides 2 Concert Freestyle"
# "In My Lifetime, Vol. 1 [Album Art]" is not valid. Skipping.
# Song 352: "Girls, Girls, Girls (MTV Unplugged)"
# Song 353: "Warm It Up"
# Song 354: "Jigga That N**** (MTV Unplugged)"
# Song 355: "Decoded: Part 4 (Excerpts)"
# "In My Lifetime, Vol. 1 [Credits]" is not valid. Skipping.
# Song 356: "Freestyle"
# Song 357: "On To The Next One [Jay-Z + Swizz Beatz]"
# Song 358: "Nuthin' But Love"
# Song 359: "Can't Knock The Hustle/Family Affair"
# Song 360: "Spiritual Statement"
# Song 361: "If You Want It"
# Song 362: "Heart Of The City (Ain't No Love) - Album Version (Edited)"
# Song 363: "Hard Knock Life (MTV Unplugged)"
# Song 364: "Wishing On A Star (D Influence Remix)**"
# Song 365: "Hyphen Hater"
# Song 366: "Ain't No (MTV Unplugged)"
# Song 367: "Jay Z Explains Why He Trademarked His Daughter's Name"
# Song 368: "First Televised Freestyle"
# Song 369: "A Word From Hov"
# Song 370: "Baby Freestyle"
# Song 371: "Tidal B-Sides Concert Freestyle"
# Song 372: "Ultra"
# Song 373: "The Scoreboard (His Top Albums)"
# Song 374: "Young Forever (Live)"
# Song 375: "I Shot Ya (Freestyle)"
# Song 376: "Kill Jay Z (Türkçe Çeviri)"
# Song 377: "Hey Papi (Original Version)"
# "On The Run II Tour Setlist" is not valid. Skipping.
# Song 378: "He Asked For It"
# Song 379: "Murda Murda (feat. Memphis Bleek And Beanie Sigel)"
# "Notorious B.I.G. Interview" is not valid. Skipping.
# "OG Skit" is not valid. Skipping.
# Song 380: "Picasso Baby: A Performance Art Film"
# Song 381: "Ain't No Nigga (Original Radio Edit)"
# Song 382: "Empire State of Mind (Live)"
# Song 383: "Wishing On A Star (Radio Edit)"
# Song 384: "היי"
# "The Best of Both Worlds Album Art" is not valid. Skipping.
# Song 385: "Yo cunt"
# Song 386: "On To The Next One [Jay-Z + Swizz Beatz] - Amended"
# Song 387: "Sunshine (Radio Edit)"
# "Russell Simmons Skit" is not valid. Skipping.
# Song 388: "The Story of OJ - Ms. Brown Version"
# Song 389: "A Word from the President"
# Song 390: "Greatest mc (demo)"
# Song 391: "Freestyle [Invasion II]"
# Song 392: "Ain't No Nigga (Rae & Christian Mix)"
# Song 393: "Can't Knock The Hustle (The S. Carter Collection Remix)"
# Song 394: "Live From Tweeter Center, IL (Interlude)"
# Song 395: "Intro (Kon The Louis Vuitton Don)"
# Song 396: "Holy Scriptures"
# Song 397: "Young Jeezy signs to ROC Nation"
# Song 398: "PSA (Remix)"
# Song 399: "E"
# Song 400: "Made in America Tour Expansion"
# Song 401: "Truly"
# Song 402: "Jay Z's 'Made In America' Tour Documentery Trailer Surfaces Online"
# Song 403: "Vocab"
# Song 404: "Xx"
# Song 405: "99 Problems (The Video)"
# Song 406: "99 Problems (Remix)"
# Song 407: "Give It To Me/Big Pimpin (Live)"
# Song 408: "Jay Z To Launch His Own Range of Leather Backpacks and More"
# Song 409: "03' Bonnie & Clyde (Live)"
# Song 410: "Second Statement on Barneys Controversy"
# Song 411: "Dec 4th (Remix)"
# Song 412: "P. Diddy Interlude"
# Song 413: "Where I'm From (DJ Green Lantern Mix)"
# Song 414: "Encore (Remix)"
# Song 415: "Public Service Announcement (Live"
# Song 416: "Denzel Washington Interlude"
# Song 417: "My 1st Song (Remix)"
# Song 418: "Moment of Clarity (Remix)"
# Song 419: "Run This Town (Live)"
# Song 420: "Threat (Remix) [Interlude]"
# Song 421: "On to the Next One (Live)"
# Song 422: "Michael Jordan Interlude"
# Done. Found 422 songs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fb211ba02f3f> in <module>
# ----> 1 sample_data("Jay Z")
#
# <ipython-input-6-34c7ac4fd54a> in sample_data(artist_func)
#       6     x=0
#       7     for item in artist_1.songs:
# ----> 8         titles.append(artist_1.songs[x].title)
#       9         x+=1
#      10
#
# NameError: name 'titles' is not defined

# %%
# df.to_pickle(artist_func + "_data")
# df = pd.read_pickle(file_name)
