# %%
import spotipy
import pandas as pd
from pprint import pprint
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import spotipy.oauth2 as oauth2
from bs4 import BeautifulSoup
from api_key import genius_api_key_id

from api_key import genius_client_id
from api_key import genius_client_secret
from api_key import SPOTIFY_CLIENT_ID
from api_key import SPOTIFY_CLIENT_SECRET
import lyricsgenius


# credentials = oauth2.SpotifyClientCredentials(
#        client_id=SPOTIFY_CLIENT_ID,
#        client_secret=SPOTIFY_CLIENT_SECRET)

# token = credentials.get_access_token()
# spotify = spotipy.Spotify(auth=token)

###EMPLOYS THE lyricsgenius library: https://github.com/johnwmillr/LyricsGenius

# %%
genius = lyricsgenius.Genius(genius_api_key_id)

# %%
def samples(self):
    return self._body.get('song_relationships')

# %%
# artist_samples=[]
# for y in range(len(artist.songs)):
#     songs_sampled=[]
# #     print('---------'+ artist.songs[y].title+' samples ----------')
#     for x in range(len(artist.songs[y]._body.get('song_relationships')[0]['songs'])):
#         songs_sampled.append({artist.songs[y]._body.get('song_relationships')[0]['songs'][x]['primary_artist']['name']:artist.songs[y]._body.get('song_relationships')[0]['songs'][x]['title']})
#     artist_samples.append({artist.songs[y].title:songs_sampled})
# #     print(songs_sampled)
# #     print('-------------------')

# %%
# sampledin_list=[]
# for x in range(len(artist.songs)):
#     sampled_in=[]
#     if len(artist.songs[x]._body.get('song_relationships')[1]['songs']) > 0:
#         for y in range(len(artist.songs[x]._body.get('song_relationships')[1]['songs'])):
#     #         pprint(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['primary_artist']['name'])
#             sampled_in.append({(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['primary_artist']['name']):(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['title'])})
#     else:
#         sampled_in.append([])
#     sampledin_list.append(sampled_in)

# %%
artist = genius.search_artist("Eminem", max_songs="", sort="title")

artist_samples=[]
for y in range(len(artist.songs)):
    songs_sampled=[]
#     print('---------'+ artist.songs[y].title+' samples ----------')
    for x in range(len(artist.songs[y]._body.get('song_relationships')[0]['songs'])):
        songs_sampled.append({artist.songs[y]._body.get('song_relationships')[0]['songs'][x]['primary_artist']['name']:artist.songs[y]._body.get('song_relationships')[0]['songs'][x]['title']})
    artist_samples.append({artist.songs[y].title:songs_sampled})
#     print(songs_sampled)
#     print('-------------------')


sampledin_list=[]
for x in range(len(artist.songs)):
    sampled_in=[]
    if len(artist.songs[x]._body.get('song_relationships')[1]['songs']) > 0:
        for y in range(len(artist.songs[x]._body.get('song_relationships')[1]['songs'])):
    #         pprint(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['primary_artist']['name'])
            sampled_in.append({(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['primary_artist']['name']):(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['title'])})
    else:
        sampled_in.append([])
    sampledin_list.append(sampled_in)

df=pd.DataFrame()
df_songs=[]
df_artist=[]
df_writers=[]
df_writers=[]
df_year=[]
df_samples=[]
df_album=[]
df_samples_per_song=[]
df_featured_artists=[]
df_lyrics=[]
df_img=[]
a=[]
df_sampled_in=[]
df_api=[]
df_path=[]
df_description=[]
df_id=[]
df_stats=[]
df_pageviews=[]
df_apple_music_player_url=[]
df_recording_location=[]
df_release_date=[]

df_writers_per_song=[]
for x in range(len(artist._songs)):
    df_songs.append(artist._songs[x].title)
    df_artist.append(artist._songs[x].artist)
    df_writers_per_song=[]
    for y in range(len(artist._songs[x].writer_artists)):
        df_writers_per_song.append(artist._songs[x].writer_artists[y]['name'])
    df_writers.append(df_writers_per_song)
    df_samples.append(list(artist_samples[x].values())[0])
    df_album.append(artist.songs[x].album)
    df_year.append(artist.songs[x].year)
    df_img.append(artist.songs[x].song_art_image_url)

    featured_artists=[]
    featured_list=[]
    y=0
    featured_list=[]
    if artist._songs[x].featured_artists == a:
        featured_artists.append([])
    else:
        for y in range(len(artist._songs[x].featured_artists)):
            featured_list.append(artist._songs[x].featured_artists[y]['name'])
    df_featured_artists.append(featured_list)
    lyrics=artist.songs[x].to_dict
    df_lyrics.append(lyrics()['lyrics'])

    sampled_in=[]
    if len(artist.songs[x]._body.get('song_relationships')[1]['songs']) > 0:
        for y in range(len(artist.songs[x]._body.get('song_relationships')[1]['songs'])):
            sampled_in.append({(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['primary_artist']['name']):(artist.songs[x]._body.get('song_relationships')[1]['songs'][y]['title'])})
    else:
        sampled_in.append([])
    df_sampled_in.append(sampled_in)
    df_api.append(artist._songs[x]._body['api_path'])
    df_path.append(artist._songs[x]._body['url'])
    df_id.append(artist._songs[x]._body['id'])
    df_description.append(artist._songs[x]._body['description'])
    df_apple_music_player_url.append(artist._songs[x]._body['apple_music_player_url'])
    df_recording_location.append(artist._songs[x]._body['recording_location'])
    df_release_date.append(artist._songs[x]._body['release_date'])
    df_stats.append(artist._songs[x]._body['stats'])
    try:
        df_pageviews.append(artist._songs[x]._body['stats']['pageviews'])
    except:
        df_pageviews.append("null")



df['Performer']=df_artist
df['Song']=df_songs
df['Album']=df_album
df['Year']=df_year
df['Featuring']=df_featured_artists
df['Writers']=df_writers
df['Samples']=df_samples
df['Sampled_In']=df_sampled_in
df['Lyrics']=df_lyrics
df['Image_URL']=df_img
df['Description']=df_description
df['API_path']=df_api
df['URL']=df_path
df['Release_Date']=df_release_date

df['Music_Player_URL']=df_apple_music_player_url
df['Song_Id']=df_id
df["Recording_Location"]=df_recording_location
df['Stats']=df_stats
df['Pageviews']=df_pageviews
# Out:
# Searching for songs by Eminem...
#
# Song 1: "12 Days of Diss-Mas"
# Song 2: "1-833-2GET-REV (REVIVAL Voicemail)"
# Song 3: "1996 Underground Freestyle"
# Song 4: "1997 Freestyle Live at Wetlands, NYC"
# Song 5: "1997 Rap Olympics"
# Song 6: "1999"
# Song 7: "2004 Tim Westwood Freestyle"
# Song 8: "2012 Something From Nothing: Art of Rap Freestyle"
# Song 9: "2.0 Boys"
# Song 10: "25 to Life"
# Song 11: "313"
# Song 12: "3 a.m."
# Song 13: "3 Verses"
# Song 14: "4 Verses"
# Song 15: "50 Ways"
# Song 16: "8 Mile"
# Song 17: "8 Mile: 313 Cypher (Chin Tiki Girls)"
# Song 18: "8 Mile Background Music"
# Song 19: "8 Mile: B-Rabbit vs Papa Doc"
# Song 20: "8 Mile: B-Rabbit vs Supa Emcee"
# Song 21: "8 Mile: Cheddar Bob Freestyle"
# Song 22: "8 Mile: D'Phuzion vs B-Rabbit"
# Song 23: "8 Mile: Lily's Lullaby"
# Song 24: "8 Mile: Lotto vs B-Rabbit"
# Song 25: "8 Mile: Lyckety-Splyt vs B-Rabbit"
# Song 26: "8 Mile: Marv Won vs B-Rabbit"
# Song 27: "8 Mile: Maurice Grant vs B-Rabbit"
# Song 28: "8 Mile: Sweet Home Alabama Freestyle"
# Song 29: "8 Mile: The Lunch Truck Battle"
# Song 30: "'97 Blazer"
# Song 31: "97' Bonnie & Clyde"
# Song 32: "'99 Tim Westwood Freestyle"
# Song 33: "Almost Famous"
# Song 34: "Amityville"
# Song 35: "Anger Management"
# Song 36: "Anger Management (Turkish Translation)"
# Song 37: "Any Man (Fucking Crazy)"
# Song 38: "Any Word Freestyle"
# Song 39: "Ariel"
# Song 40: "Armaggedon (The Invasion Part 3)"
# Song 41: "Arose"
# Song 42: "Asshole"
# Song 43: "Ass Like That"
# Song 44: "As the World Turns"
# Song 45: "Baby"
# Song 46: "Backstabber"
# Song 47: "Bad Guy"
# Song 48: "Bad Husband"
# Song 49: "Bad Influence"
# Song 50: "Bad Meets Evil"
# Song 51: "Bad Meets Evil Original"
# Song 52: "Bagpipes from Baghdad"
# Song 53: "Ballin' Uncontrollably"
# Song 54: "Baruch College Session"
# Song 55: "Beautiful"
# Song 56: "Beautiful Pain"
# Song 57: "Beautiful (Radio Edit)"
# Song 58: "Believe"
# "Benzino II (Skit)" is not valid. Skipping.
# Song 59: "Berzerk"
# Song 60: "Berzerk Explained"
# Song 61: "Berzerk Single Art"
# Song 62: "BET Shady 2.0 Cypher"
# Song 63: "Big Weenie"
# Song 64: "Bitch Please II"
# "Bitch (Skit)" is not valid. Skipping.
# "Bizarre (Skit) [2004]" is not valid. Skipping.
# Song 65: "Bjorn Ironside"
# Song 66: "Brain Damage"
# Song 67: "Brain Damage (Snippet)"
# Song 68: "Brainless"
# Song 69: "Breaking Bad"
# Song 70: "Breaking News"
# Song 71: "Breaking News - Intro"
# Song 72: "Brenda"
# Song 73: "Broke Day (Snippet of "It's Okay")"
# Song 74: "Broken Rubber"
# Song 75: "Buffalo Bill"
# Song 76: "Bully"
# Song 77: "Bump Heads (Ja Rule Diss)"
# Song 78: "Business"
# Song 79: "Business (Remix)"
# Song 80: "Business Single Art"
# Song 81: "Calm Before the Storm"
# Song 82: "Campaign Speech"
# Song 83: "Cancerous (Freestyle)"
# Song 84: "Can I Bitch (Canibus Diss)"
# Song 85: "Careful What You Wish For"
# Song 86: "Castle"
# Song 87: "Celebrity (Freestyle)"
# Song 88: "Chloraseptic"
# Song 89: "Chloraseptic (Remix)"
# Song 90: "Cinderella Man"
# Song 91: "Cleanin' Out My Closet"
# Song 92: "Cleanin' Out My Closet (Drum & Bass Remix)"
# Song 93: "Cleanin' Out My Closet Single Art"
# Song 94: "C'mon Everybody"
# Song 95: "Cocaine"
# Song 96: "Cock Massage"
# Song 97: "Cold Wind Blows"
# Song 98: "Conglomerate"
# Song 99: "Countdown"
# Song 100: "Crack a Bottle"
# Song 101: "Crack a Bottle (Original Demo)"
# Song 102: "Crack A Bottle (Shady Remix)"
# Song 103: "Crackers And Cheese"
# Song 104: "Crazy in Love"
# Song 105: "Criminal"
# Song 106: "Criminal (Snippet)"
# Song 107: "Cum on Everybody"
# "Curtain Call [Tracklist + Album Artwork]" is not valid. Skipping.
# "Curtains Close (Skit)" is not valid. Skipping.
# "Curtains Up (Skit)" is not valid. Skipping.
# "Curtains Up (Skit) [2004]" is not valid. Skipping.
# "Curtis (Skit)" is not valid. Skipping.
# Timeout raised and caught:
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-01563c0864e3> in <module>
#       1
#       2
# ----> 3 artist = genius.search_artist("Eminem", max_songs="", sort="title")
#       4
#       5 artist_samples=[]
#
# /anaconda3/lib/python3.7/site-packages/lyricsgenius/api.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info)
#     305                 else:
#     306                     info = {'song': song_info}
# --> 307                 song = Song(info, lyrics)
#     308
#     309                 # Attempt to add the Song to the Artist
#
# /anaconda3/lib/python3.7/site-packages/lyricsgenius/song.py in __init__(self, json_dict, lyrics)
#      24             save_lyrics: Save the song lyrics to a JSON or TXT file.
#      25         """
# ---> 26         self._body = json_dict['song'] if 'song' in json_dict else json_dict
#      27         self._body['lyrics'] = lyrics
#      28         self._url = self._body['url']
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
df.to_pickle("Eminem_data")
# df = pd.read_pickle(file_name)
